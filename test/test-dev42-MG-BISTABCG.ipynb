# %% [markdown]
# # Init for pyqcu.

# %%
import cupy as cp
import numpy as np
import functools
from pyqcu.cuda import define
from pyqcu.cuda import io
from pyqcu.cuda import qcu
from pyqcu.cuda import eigen, cg, bistabcg
from time import perf_counter
from opt_einsum import contract
from pyqcu.cuda.set import params, argv, set_ptrs
params[define._NODE_RANK_] = define.rank
params[define._NODE_SIZE_] = define.size
kappa = 1 / (2 * argv[define._MASS_] + 8)
print('My rank is ', define.rank)
gauge_filename = f"quda_wilson-bistabcg-gauge_-{params[define._LAT_X_]}-{params[define._LAT_Y_]}-{params  [define._LAT_Z_]}-{params[define._LAT_T_]}-{params[define._LAT_XYZT_]}-{params[define._GRID_X_]}-{params[define._GRID_Y_]}-{params[define._GRID_Z_]}-{params[define._GRID_T_]}-{params[define._PARITY_]}-{params[define._NODE_RANK_]}-{params[define._NODE_SIZE_]}-{params[define._DAGGER_]}-f.h5"
print("Parameters:", params)
params[define._MG_X_] = 8
params[define._MG_Y_] = 8
params[define._MG_Z_] = 8
params[define._MG_T_] = 8

# %%
wilson_cg_params = params.copy()
wilson_cg_params[define._SET_INDEX_] = 0
wilson_cg_params[define._SET_PLAN_] = define._SET_PLAN1_
qcu.applyInitQcu(set_ptrs, wilson_cg_params, argv)

# %%
wilson_dslash_eo_params = params.copy()
wilson_dslash_eo_params[define._SET_INDEX_] = 1
wilson_dslash_eo_params[define._SET_PLAN_] = define._SET_PLAN0_
wilson_dslash_eo_params[define._PARITY_] = define._EVEN_
wilson_dslash_eo_params[define._DAGGER_] = define._NO_USE_
qcu.applyInitQcu(set_ptrs, wilson_dslash_eo_params, argv)

# %%
wilson_dslash_eo_dag_params = params.copy()
wilson_dslash_eo_dag_params[define._SET_INDEX_] = 2
wilson_dslash_eo_dag_params[define._SET_PLAN_] = define._SET_PLAN0_
wilson_dslash_eo_dag_params[define._PARITY_] = define._EVEN_
wilson_dslash_eo_dag_params[define._DAGGER_] = define._USE_
qcu.applyInitQcu(set_ptrs, wilson_dslash_eo_dag_params, argv)

# %%
wilson_dslash_oe_params = params.copy()
wilson_dslash_oe_params[define._SET_INDEX_] = 3
wilson_dslash_oe_params[define._SET_PLAN_] = define._SET_PLAN0_
wilson_dslash_oe_params[define._PARITY_] = define._ODD_
wilson_dslash_oe_params[define._DAGGER_] = define._NO_USE_
qcu.applyInitQcu(set_ptrs, wilson_dslash_oe_params, argv)

# %%
wilson_dslash_oe_dag_params = params.copy()
wilson_dslash_oe_dag_params[define._SET_INDEX_] = 4
wilson_dslash_oe_dag_params[define._SET_PLAN_] = define._SET_PLAN0_
wilson_dslash_oe_dag_params[define._PARITY_] = define._ODD_
wilson_dslash_oe_dag_params[define._DAGGER_] = define._USE_
qcu.applyInitQcu(set_ptrs, wilson_dslash_oe_dag_params, argv)

# %%
print("Set pointers:", set_ptrs)
print("Set pointers data:", set_ptrs.data)

# %% [markdown]
# # Read from hdf5 files.

# %%
print("Gauge filename:", gauge_filename)
gauge = io.hdf5_xxxtzyx2grid_xxxtzyx(params, gauge_filename)
fermion_in_filename = gauge_filename.replace("gauge", "fermion-in")
print("Fermion in filename:", fermion_in_filename)
fermion_in = io.hdf5_xxxtzyx2grid_xxxtzyx(
    params, fermion_in_filename)
fermion_out_filename = gauge_filename.replace("gauge", "fermion-out")
print("Fermion out filename:", fermion_out_filename)
quda_fermion_out = io.hdf5_xxxtzyx2grid_xxxtzyx(
    params, fermion_out_filename)
fermion_out = cp.zeros_like(fermion_in)
print("Fermion out data:", fermion_out.data)
print("Fermion out shape:", fermion_out.shape)
# eigenvalues_filename = gauge_filename.replace("gauge", "eigenvalues")
# print("Eigenvalues filename:", eigenvalues_filename)
# eigenvalues = io.hdf5_xxx2xxx(file_name=eigenvalues_filename)
# print("Eigenvalues data:", eigenvalues.data)
# print("Eigenvalues shape:", eigenvalues.shape)
eigenvectors_filename = gauge_filename.replace("gauge", "eigenvectors")
print("Eigenvectors filename:", eigenvectors_filename)
eigenvectors = io.eigenvectors2esctzyx(
    params=params, eigenvectors=io.hdf5_xxx2xxx(file_name=eigenvectors_filename))
print("Eigenvectors data:", eigenvectors.data)
print("Eigenvectors shape:", eigenvectors.shape)

# %% [markdown]
# # Run wilson bistabcg from pyqcu test.

# %%
qcu.applyWilsonBistabCgQcu(fermion_out, fermion_in,
                           gauge, set_ptrs, wilson_cg_params)
# qcu.applyWilsonCgQcu(fermion_out, fermion_in,
#                            gauge, set_ptrs, wilson_cg_params)
print("Fermion out data:", fermion_out.data)
print("Fermion out shape:", fermion_out.shape)
print("QUDA Fermion out data:", quda_fermion_out.data)
print("QUDA Fermion out shape:", quda_fermion_out.shape)
print("Difference:", cp.linalg.norm(fermion_out -
      quda_fermion_out)/cp.linalg.norm(quda_fermion_out))

# %% [markdown]
# # Give CG & BISTABCG Dslash.
# > src_o-set_ptr->kappa()**2*dslash_oe(dslash_eo(src_o))

# %%
def cg_dslash_no_dag(src):
    tmp0 = cp.zeros_like(src)
    tmp1 = cp.zeros_like(src)
    qcu.applyWilsonDslashQcu(
        tmp0, src, gauge, set_ptrs, wilson_dslash_eo_params)
    qcu.applyWilsonDslashQcu(
        tmp1, tmp0, gauge, set_ptrs, wilson_dslash_oe_params)
    return src-kappa**2*tmp1


def cg_dslash_dag(src):
    tmp0 = cp.zeros_like(src)
    tmp1 = cp.zeros_like(src)
    qcu.applyWilsonDslashQcu(
        tmp0, src, gauge, set_ptrs, wilson_dslash_eo_dag_params)
    qcu.applyWilsonDslashQcu(
        tmp1, tmp0, gauge, set_ptrs, wilson_dslash_oe_dag_params)
    return src-kappa**2*tmp1


def cg_dslash(src):
    return cg_dslash_dag(cg_dslash_no_dag(src))

def bistabcg_dslash(src):
    return cg_dslash_no_dag(src)

# %% [markdown]
# # Give matvec.

# %%
def matvec(src):
    return cg_dslash(src)

# %% [markdown]
# # Run matvec(eigenvector[.]) ?= eigenvalue[.]*eigenvector[.] for eigen test. (pass, don't run this)

# %%
# for i, ev in enumerate(eigenvalues):
#     print(f"λ_{i} = {ev:.2e}")
#     # Verify eigenvector
#     v = eigenvectors[i]
#     w = cp.zeros_like(v)
#     w = cg_dslash(v)
#     error = cp.linalg.norm(w - ev * v) / cp.linalg.norm(w)
#     print(f"Relative error: {error:.2e}")
#     j = i+1
#     if j == len(eigenvalues):
#         j = 0
#     print(
#         f"Diff between λ_{i} and λ_{j}: {cp.linalg.norm(eigenvectors[i] - eigenvectors[j])/cp.linalg.norm(eigenvectors[i]):.2e}")

# %% [markdown]
# # Give guage's eigenvalues and eigenvectors to hdf5 files. (pass, don't run this)

# %%
# eigenvalues, eigenvectors = eigen.solver(
#     n=params[define._LAT_XYZT_] * define._LAT_HALF_SC_, k=params[define._LAT_E_],matvec=cg_dslash,dtype=gauge.dtype)
# io.xxx2hdf5_xxx(
#     eigenvalues, params, gauge_filename.replace("gauge", "eigenvalues"))
# io.xxx2hdf5_xxx(
#     eigenvectors, params, gauge_filename.replace("gauge", "eigenvectors"))

# %% [markdown]
# # Origin CG. (pass, don't run this)

# %%
# b_e = fermion_in[define._EVEN_].flatten()
# b_o = fermion_in[define._ODD_].flatten()
# b__o = cp.zeros_like(b_o)
# tmp = cp.zeros_like(b_o)
# # b__o=b_o+kappa*D_oe(b_e)
# qcu.applyWilsonDslashQcu(tmp, b_e, gauge, set_ptrs, wilson_dslash_oe_params)
# b__o = b_o+kappa*tmp
# # b__o -> Dslash^dag b__o
# b__o = cg_dslash_dag(b__o)
# # Dslash(x_o)=b__o
# x_o = cg.slover(b=b__o, matvec=cg_dslash, tol=1e-10, max_iter=1000000)
# # x_e  =b_e+kappa*D_eo(x_o)
# qcu.applyWilsonDslashQcu(tmp, x_o, gauge, set_ptrs, wilson_dslash_eo_params)
# x_e = b_e+kappa*tmp
# # give qcu_fermion_out
# qcu_fermion_out = cp.zeros_like(quda_fermion_out)
# qcu_fermion_out[define._EVEN_] = x_e.reshape(
#     quda_fermion_out[define._EVEN_].shape)
# qcu_fermion_out[define._ODD_] = x_o.reshape(
#     quda_fermion_out[define._ODD_].shape)
# print(np.linalg.norm(qcu_fermion_out-quda_fermion_out) /
#       np.linalg.norm(quda_fermion_out))

# %% [markdown]
# # Origin BISTABCG. (pass, don't run this)

# %%
# b_e = fermion_in[define._EVEN_].flatten()
# b_o = fermion_in[define._ODD_].flatten()
# b__o = cp.zeros_like(b_o)
# tmp = cp.zeros_like(b_o)
# # b__o=b_o+kappa*D_oe(b_e)
# qcu.applyWilsonDslashQcu(tmp, b_e, gauge, set_ptrs, wilson_dslash_oe_params)
# b__o = b_o+kappa*tmp
# # Dslash(x_o)=b__o
# x_o = bistabcg.slover(
#     b=b__o, matvec=bistabcg_dslash, tol=1e-10, max_iter=1000000)
# # x_e  =b_e+kappa*D_eo(x_o)
# qcu.applyWilsonDslashQcu(tmp, x_o, gauge, set_ptrs, wilson_dslash_eo_params)
# x_e = b_e+kappa*tmp
# # give qcu_fermion_out
# qcu_fermion_out = cp.zeros_like(quda_fermion_out)
# qcu_fermion_out[define._EVEN_] = x_e.reshape(
#     quda_fermion_out[define._EVEN_].shape)
# qcu_fermion_out[define._ODD_] = x_o.reshape(
#     quda_fermion_out[define._ODD_].shape)
# print(np.linalg.norm(qcu_fermion_out-quda_fermion_out) / \
#     np.linalg.norm(quda_fermion_out))

# %% [markdown]
# # Give guage's orth_eigenvectors to hdf5 files. (pass, don't run this)

# %%
# _eigenvectors = io.xxxtzyx2mg_xxxtzyx(input_array=eigenvectors, params=params)
# _eigenvectors.shape  # escTtZzYyXx
# def orthogonalize(eigenvectors):
#     _eigenvectors = eigenvectors.copy()
#     size_e, size_s, size_c, size_T, size_t, size_Z, size_z, size_Y, size_y, size_X, size_x = eigenvectors.shape
#     print(size_e, size_s, size_c, size_T, size_t,
#           size_Z, size_z, size_Y, size_y, size_X, size_x)
#     for T in range(size_T):
#         for Z in range(size_Z):
#             for Y in range(size_Y):
#                 for X in range(size_X):
#                     origin_matrix = eigenvectors[:,
#                                                  :, :, T, :, Z, :, Y, :, X, :]
#                     _shape = origin_matrix.shape
#                     _origin_matrix = origin_matrix.reshape(size_e, -1)
#                     condition_number = np.linalg.cond(_origin_matrix.get())
#                     print(f"矩阵条件数: {condition_number}")
#                     a = _origin_matrix[:, 0]
#                     b = _origin_matrix[:, -1]
#                     print(cp.dot(a.conj(), b))
#                     Q = cp.linalg.qr(_origin_matrix.T)[0]
#                     condition_number = np.linalg.cond(Q.get())
#                     print(f"矩阵条件数: {condition_number}")
#                     a = Q[:, 0]
#                     b = Q[:, -1]
#                     print(cp.dot(a.conj(), b))
#                     _eigenvectors[:, :, :, T, :, Z, :, Y, :, X, :] = Q.T.reshape(
#                         _shape)
#     return _eigenvectors
# orth_eigenvectors = orthogonalize(_eigenvectors)
# io.xxx2hdf5_xxx(
#     orth_eigenvectors, params, gauge_filename.replace("gauge", "orth_eigenvectors"))

# %% [markdown]
# # MultiGrid - give grids.

# %%
orth_eigenvectors_filename = gauge_filename.replace("gauge", "orth_eigenvectors")
print("Orth orth_eigenvectors filename:", orth_eigenvectors_filename)
orth_eigenvectors = io.eigenvectors2esctzyx(
    params=params, eigenvectors=io.hdf5_xxx2xxx(file_name=orth_eigenvectors_filename))
print("Orth orth_eigenvectors data:", orth_eigenvectors.data)
print("Orth orth_eigenvectors shape:", orth_eigenvectors.shape)
testvectors = io.xxxtzyx2mg_xxxtzyx(input_array=orth_eigenvectors, params=params)
_src = io.xxxtzyx2mg_xxxtzyx(
    input_array=fermion_in[define._EVEN_], params=params)
# _src = io.xxxtzyx2mg_xxxtzyx(
#     input_array=fermion_out[define._EVEN_], params=params)

# %% [markdown]
# <!-- # MultiGrid - R*vector.
# ![](./image0-dev40.png) -->

# %%
r_src = _src


def r_vec(src):
    return contract("escTtZzYyXx,scTtZzYyXx->eTZYX", testvectors, src)


r_dest = r_vec(r_src)

# %%
r_dest.shape

# %% [markdown]
# <!-- # MultiGrid - P*vector.
# ![](./image1-dev40.png) -->

# %%
p_src = r_dest


def p_vec(src):
    return contract("escTtZzYyXx,eTZYX->scTtZzYyXx", cp.conj(testvectors), src)


p_dest = p_vec(p_src)

# %%
p_dest.shape

# %% [markdown]
# <!-- # MultiGrid - verify above.
# ![](./image2-dev40.png) -->

# %%
print(cp.linalg.norm(r_src))
print(cp.linalg.norm(p_dest))

# %%
print(cp.linalg.norm(r_src-p_dest)/cp.linalg.norm(r_src))

# %%
print(cp.linalg.norm(r_src-p_vec(r_vec(r_src)))/cp.linalg.norm(r_src))

# %%
r_src.flatten()[:50]

# %%
p_dest.flatten()[:50]

# %%
cp.linalg.norm(r_src-p_dest)/cp.linalg.norm(r_src)

# %%
cp.linalg.norm(r_src-p_dest)/cp.linalg.norm(p_dest)

# %%
p_vec(r_vec(p_vec(r_vec(p_vec(r_vec(p_vec(r_vec(r_src)))))))).flatten()[:50]

# %%
cp.linalg.norm(r_src-p_vec(r_vec(p_vec(r_vec(p_vec(r_vec(p_vec(r_vec(r_src)))))))))/cp.linalg.norm(r_src) #???

# %%
# _mat = contract("escTtZzYyXx,escTtZzYyXx->scTtZzYyXx",
#                 testvectors, cp.conj(testvectors)).flatten()
# print(cp.linalg.norm(_mat))
# print(_mat[:100])

# %% [markdown]
# # MultiGrid - R*matvec\*P.

# %%
def _r_matvec_p(src, matvec):
    return r_vec(matvec(p_vec(io.xxx2eTZYX(src, params))))


def r_matvec_p(src, matvec):
    return io.array2xxx(_r_matvec_p(src, matvec))

# %% [markdown]
# # MultiGrid - verify above.

# %%
D_r_src = matvec(r_src)

# %%
D_r_src.flatten()[:50]

# %%
p_r_D_p_r_dest = p_vec(_r_matvec_p(r_vec(r_src), matvec=cg_dslash))

# %%
p_r_D_p_r_dest.flatten()[:50]

# %%
cp.linalg.norm(D_r_src-p_r_D_p_r_dest)/cp.linalg.norm(D_r_src)

# %% [markdown]
# # MultiGrid - BISTABCG (TESTING......)

# %%
b_e = fermion_in[define._EVEN_].flatten()
b_o = fermion_in[define._ODD_].flatten()
b__o = cp.zeros_like(b_o)
tmp = cp.zeros_like(b_o)
# b__o=b_o+kappa*D_oe(b_e)
qcu.applyWilsonDslashQcu(tmp, b_e, gauge, set_ptrs, wilson_dslash_oe_params)
b__o = b_o+kappa*tmp

# %%
# # Dslash(x_o)=b__o
x_o = bistabcg.slover(
    b=b__o, matvec=bistabcg_dslash, tol=1e-10, max_iter=1000000)
io.xxx2hdf5_xxx(x_o, params, 'x_o.h5')

# %%
# mg version
mg_b__o = r_vec(io.xxxtzyx2mg_xxxtzyx(io.fermion2sctzyx(b__o, params), params)).flatten()
mg_x_o = bistabcg.slover(
    b=mg_b__o, matvec=functools.partial(r_matvec_p, matvec=bistabcg_dslash), tol=1e-10, max_iter=1000000)
_x_o=io.array2xxx(p_vec(io.xxx2eTZYX(mg_x_o, params)))
io.xxx2hdf5_xxx(_x_o, params, '_x_o.h5')

# %% [markdown]
# # MG-BISTABCG

# %%
def slover(b, matvec, max_iter=1000, tol=1e-9, x0=None):
    n = b.size
    dtype = b.dtype
    buffers = {key: cp.zeros(n, dtype=dtype)
               for key in ['r', 'r_tilde', 'p', 'v', 's', 't', 'x']}
    x0 = None if x0 is None else x0.copy()

    def initialize_random_vector(v):
        v.real, v.imag = cp.random.randn(n).astype(
            v.real.dtype), cp.random.randn(n).astype(v.imag.dtype)
        norm = cp.linalg.norm(v)
        if norm > 0:
            cp.divide(v, norm, out=v)
        return v

    def dot(x, y):
        return cp.sum(x.conj() * y)

    def _r_vec(src):
        return r_vec(io.xxxtzyx2mg_xxxtzyx(io.fermion2sctzyx(src, params), params)).flatten()

    def _p_vec(src):
        return p_vec(io.xxx2eTZYX(src, params)).flatten()

    def _r_matvec_p(src):
        return _r_vec(matvec(_p_vec(src)))

    x, r, r_tilde, p, v, s, t = buffers['x'], buffers['r'], buffers[
        'r_tilde'], buffers['p'], buffers['v'], buffers['s'], buffers['t']
    if x0 is not None:
        cp.copyto(x, x0)
    else:
        initialize_random_vector(x)
    r = b - matvec(x)
    cp.copyto(r_tilde, r)
    rho_prev = 1.0
    alpha = 1.0
    omega = 1.0
    start_time = perf_counter()
    iter_times = []
    for i in range(max_iter):
        iter_start_time = perf_counter()
        rho = dot(r_tilde, r)
        beta = (rho/rho_prev)*(alpha/omega)
        rho_prev = rho
        p = r+(p-v*omega)*beta
        r_norm2 = dot(r, r)
        v = matvec(p)
        alpha = rho / dot(r_tilde, v)
        s = r-v*alpha
        t = matvec(s)
        omega = dot(t, s)/dot(t, t)
        r = s-t*omega  # update r
        # COARSE START
        r_c = _r_vec(r)
        e_c = bistabcg.slover(b=r_c, matvec=_r_matvec_p,
                              tol=1e-2, max_iter=100)
        e = _p_vec(e_c)
        # COARSE END
        # FINE START
        # x = x+p*alpha+s*omega # update x # don't use ?
        x += e  # just this like?
        # FINE END
        iter_time = perf_counter() - iter_start_time
        print(
            f"@@@Iteration {i}: Residual = {r_norm2.real:.6e}, Time = {iter_time:.6f} s")
        iter_times.append(iter_time)
        if r_norm2.real < tol:
            print(
                f"@@@Converged at iteration {i} with residual {r_norm2.real:.6e}")
            break
    total_time = perf_counter() - start_time
    avg_iter_time = sum(iter_times) / len(iter_times)
    print("\nPerformance Statistics:")
    print(f"Total time: {total_time:.6f} s")
    print(f"Average time per iteration: {avg_iter_time:.6f} s")
    return x.copy()

# %%
def slover(b, matvec, max_iter=1000, tol=1e-9, x0=None):
    n = b.size
    dtype = b.dtype
    buffers = {key: cp.zeros(n, dtype=dtype)
               for key in ['r', 'r_tilde', 'p', 'v', 's', 't', 'x']}
    x0 = None if x0 is None else x0.copy()

    def initialize_random_vector(v):
        v.real, v.imag = cp.random.randn(n).astype(
            v.real.dtype), cp.random.randn(n).astype(v.imag.dtype)
        norm = cp.linalg.norm(v)
        if norm > 0:
            cp.divide(v, norm, out=v)
        return v

    def dot(x, y):
        return cp.sum(x.conj() * y)

    def _r_vec(src):
        return r_vec(io.xxxtzyx2mg_xxxtzyx(io.fermion2sctzyx(src, params), params)).flatten()

    def _p_vec(src):
        return p_vec(io.xxx2eTZYX(src, params)).flatten()

    def _r_matvec_p(src):
        return _r_vec(matvec(_p_vec(src)))

    x, r, r_tilde, p, v, s, t = buffers['x'], buffers['r'], buffers[
        'r_tilde'], buffers['p'], buffers['v'], buffers['s'], buffers['t']
    if x0 is not None:
        cp.copyto(x, x0)
    else:
        initialize_random_vector(x)
    r = b - matvec(x)
    cp.copyto(r_tilde, r)
    rho_prev = 1.0
    alpha = 1.0
    omega = 1.0
    start_time = perf_counter()
    iter_times = []
    for i in range(max_iter):
        iter_start_time = perf_counter()
        rho = dot(r_tilde, r)
        beta = (rho/rho_prev)*(alpha/omega)
        rho_prev = rho
        p = r+(p-v*omega)*beta
        r_norm2 = dot(r, r)
        v = matvec(p)
        alpha = rho / dot(r_tilde, v)
        s = r-v*alpha
        t = matvec(s)
        omega = dot(t, s)/dot(t, t)
        r = s-t*omega
        x = x+p*alpha+s*omega
        # COARSE START
        r = b-matvec(x)
        r_c = _r_vec(r)
        e_c = bistabcg.slover(b=r_c, matvec=_r_matvec_p,
                              tol=1e-2, max_iter=100)
        # COARSE END
        # FINE START
        e = _p_vec(e_c)
        x += e  # or just this like?
        r = b-matvec(x)
        # FINE END
        iter_time = perf_counter() - iter_start_time
        print(
            f"@@@Iteration {i}: Residual = {r_norm2.real:.6e}, Time = {iter_time:.6f} s")
        iter_times.append(iter_time)
        if r_norm2.real < tol:
            print(
                f"@@@Converged at iteration {i} with residual {r_norm2.real:.6e}")
            break
    total_time = perf_counter() - start_time
    avg_iter_time = sum(iter_times) / len(iter_times)
    print("\nPerformance Statistics:")
    print(f"Total time: {total_time:.6f} s")
    print(f"Average time per iteration: {avg_iter_time:.6f} s")
    return x.copy()

# %%
def slover(b, matvec, max_iter=1000, tol=1e-9, x0=None):
    tol_factor = 0.1

    def initialize_random_vector(v):
        n = b.size
        v.real, v.imag = cp.random.randn(n).astype(
            v.real.dtype), cp.random.randn(n).astype(v.imag.dtype)
        norm = cp.linalg.norm(v)
        if norm > 0:
            cp.divide(v, norm, out=v)
        return v

    def dot(x, y):
        return cp.sum(x.conj() * y)

    def _r_vec(src):
        return r_vec(io.xxxtzyx2mg_xxxtzyx(io.fermion2sctzyx(src, params), params)).flatten()

    def _p_vec(src):
        return p_vec(io.xxx2eTZYX(src, params)).flatten()

    def _r_matvec_p(src):
        return _r_vec(matvec(_p_vec(src)))

    if x0 is not None:
        x = x0
    else:
        x0 = cp.zeros_like(b)
        initialize_random_vector(x0)
        x = x0
    start_time = perf_counter()
    iter_times = []
    r = b-matvec(x)
    _tol = dot(r, r).real
    for i in range(max_iter):
        iter_start_time = perf_counter()
        _tol *= tol_factor
        print(f"@@@wanted tol: {_tol}")
        x = bistabcg.slover(
            b=b, matvec=matvec, tol=tol, max_iter=5, x0=x)
        # COARSE START
        r = b-matvec(x)
        r_c = _r_vec(r)
        e_c = bistabcg.slover(b=r_c, matvec=_r_matvec_p,
                              tol=tol, max_iter=5)
        # COARSE END
        # FINE START
        e = _p_vec(e_c)
        x += e  # or just this like?
        # FINE END
        r = b-matvec(x)
        r_norm2 = dot(r, r)
        _tol = max(_tol, r_norm2.real)
        iter_time = perf_counter() - iter_start_time
        print(
            f"@@@Iteration {i}: Residual = {r_norm2.real:.6e}, Time = {iter_time:.6f} s")
        iter_times.append(iter_time)
        if r_norm2.real < tol:
            print(
                f"@@@Converged at iteration {i} with residual {r_norm2.real:.6e}")
            break
    total_time = perf_counter() - start_time
    avg_iter_time = sum(iter_times) / len(iter_times)
    print("\nPerformance Statistics:")
    print(f"Total time: {total_time:.6f} s")
    print(f"Average time per iteration: {avg_iter_time:.6f} s")
    return x.copy()

# %%
x_o = slover(
    b=b__o, matvec=bistabcg_dslash, tol=1e-10, max_iter=1000000)
# Out:
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.013351703 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.008658063 sec
# @@@wanted tol: 4974845.5
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.007035556 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003795272 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.006308488 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.006845368 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.006587841 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.007398745 sec
# Iteration 0: Residual = 4.974845e+07, Time = 0.053397 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003628640 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.006449841 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.007042343 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.005293350 sec
# Iteration 1: Residual = 3.800154e+07, Time = 0.045243 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.011616393 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002858572 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002306624 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002123980 sec
# Iteration 2: Residual = 5.909510e+06, Time = 0.040737 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002367995 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002415084 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.008093842 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003728830 sec
# Iteration 3: Residual = 3.659220e+06, Time = 0.025595 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002535899 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002127162 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003817922 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002590685 sec
# Iteration 4: Residual = 1.319323e+06, Time = 0.018638 s
#
# Performance Statistics:
# Total time: 0.259114 s
# Average time per iteration: 0.036722 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002168276 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.004640691 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002559077 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003250359 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.007398758 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002606782 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002740452 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002050343 sec
# Iteration 0: Residual = 1.808179e+06, Time = 0.123365 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002561554 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002411723 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.016622783 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002049064 sec
# Iteration 1: Residual = 2.259760e+05, Time = 0.110763 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002128586 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002571480 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001990368 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002379922 sec
# Iteration 2: Residual = 3.719161e+04, Time = 0.099537 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.017199587 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.012022305 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002020770 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002025293 sec
#
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Iteration 3: Residual = 2.897457e+04, Time = 0.141516 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002526560 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001954701 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002674289 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.010465163 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Iteration 4: Residual = 7.322448e+03, Time = 0.118924 s
#
# Performance Statistics:
# Total time: 0.678735 s
# Average time per iteration: 0.118821 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002525502 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002217286 sec
# @@@Iteration 0: Residual = 5.230752e+06, Time = 1.080949 s
# @@@wanted tol: 523075.15625
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002021023 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003490015 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002036138 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002657312 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002453951 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002524367 sec
# Iteration 0: Residual = 5.230752e+06, Time = 0.021158 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002232862 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002170908 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002496551 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.004467549 sec
# Iteration 1: Residual = 1.489373e+06, Time = 0.021654 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002849924 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.006925582 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.007087731 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002055643 sec
# Iteration 2: Residual = 1.719793e+07, Time = 0.040813 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.008767699 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002861557 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.005798102 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002963751 sec
# Iteration 3: Residual = 2.273410e+05, Time = 0.031638 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.004697518 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002451634 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002689010 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002160411 sec
# Iteration 4: Residual = 1.245888e+05, Time = 0.021486 s
#
# Performance Statistics:
# Total time: 0.174661 s
# Average time per iteration: 0.027350 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003294204 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.004406503 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.004008298 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002489699 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002100640 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.009881853 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002684735 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003063881 sec
# Iteration 0: Residual = 1.625554e+04, Time = 0.136383 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002100047 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002527779 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003680076 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.025208423 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Iteration 1: Residual = 4.096966e+03, Time = 0.134056 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002177478 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002464881 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002519066 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002188724 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Iteration 2: Residual = 9.411494e+02, Time = 0.110530 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003395614 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002649141 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002649266 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001896752 sec
# Iteration 3: Residual = 3.949953e+02, Time = 0.108669 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002512282 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.005084009 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001928738 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002489000 sec
# Iteration 4: Residual = 1.835494e+02, Time = 0.103637 s
#
# Performance Statistics:
# Total time: 0.718320 s
# Average time per iteration: 0.118655 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002447907 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002460151 sec
# @@@Iteration 1: Residual = 4.260098e+04, Time = 1.017093 s
# @@@wanted tol: 52307.515625
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.006831710 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001995426 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002888751 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002175501 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002508374 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002399787 sec
# Iteration 0: Residual = 4.260098e+04, Time = 0.018486 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002993991 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002400458 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003664058 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002508348 sec
# Iteration 1: Residual = 9.380854e+03, Time = 0.019096 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003111012 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.004975196 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003245621 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.007507234 sec
# Iteration 2: Residual = 1.032351e+04, Time = 0.027368 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.010666466 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002446275 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.005189507 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002178455 sec
# Iteration 3: Residual = 3.857148e+03, Time = 0.028424 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002643659 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002625464 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002698154 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002129190 sec
# Iteration 4: Residual = 2.896060e+03, Time = 0.019662 s
#
# Performance Statistics:
# Total time: 0.163103 s
# Average time per iteration: 0.022607 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001995641 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002354857 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002001822 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002252614 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.021121193 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.012276531 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002000347 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002412879 sec
# Iteration 0: Residual = 4.772432e+02, Time = 0.152428 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002472805 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001898059 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002865942 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.010300484 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Iteration 1: Residual = 1.507102e+02, Time = 0.116903 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002539403 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001956321 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002067978 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002418606 sec
# Iteration 2: Residual = 4.213760e+01, Time = 0.102338 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002732326 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.013725520 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002496816 sec
#
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003387813 sec
# Iteration 3: Residual = 2.061404e+01, Time = 0.125122 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002071259 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003567878 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002689477 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.009532968 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Iteration 4: Residual = 1.800194e+01, Time = 0.118008 s
#
# Performance Statistics:
# Total time: 0.702531 s
# Average time per iteration: 0.122960 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002823077 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002818553 sec
# @@@Iteration 2: Residual = 1.232934e+03, Time = 0.993724 s
# @@@wanted tol: 5230.75146484375
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002503135 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002730364 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002034402 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002442139 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002147028 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002849003 sec
# Iteration 0: Residual = 1.232934e+03, Time = 0.018157 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.004259210 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002609043 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002377914 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002780519 sec
# Iteration 1: Residual = 2.497141e+02, Time = 0.020148 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002577982 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001997986 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003248850 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.004466947 sec
# Iteration 2: Residual = 1.273586e+02, Time = 0.020960 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.015856822 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002026809 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.011340029 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002517891 sec
# Iteration 3: Residual = 6.696180e+01, Time = 0.053309 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001968118 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002480730 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002672706 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002534973 sec
# Iteration 4: Residual = 4.799397e+01, Time = 0.017964 s
#
# Performance Statistics:
# Total time: 0.161414 s
# Average time per iteration: 0.026108 s
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002072877 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002935212 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002681686 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002114802 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002445341 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.029836184 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002441202 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001921793 sec
# Iteration 0: Residual = 1.400285e+01, Time = 0.142501 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001944611 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002359982 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.016214031 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.007548071 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Iteration 1: Residual = 7.418106e+00, Time = 0.130957 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002546336 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002633930 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002242037 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002616775 sec
#
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Iteration 2: Residual = 5.673460e+00, Time = 0.106630 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.010025840 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.016982420 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002530927 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.006501483 sec
# Iteration 3: Residual = 2.336206e+00, Time = 0.142407 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002488481 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002127175 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002208571 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.011890135 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Iteration 4: Residual = 1.644953e+00, Time = 0.116575 s
#
# Performance Statistics:
# Total time: 0.734618 s
# Average time per iteration: 0.127814 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002031849 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002409383 sec
# @@@Iteration 3: Residual = 6.289201e+01, Time = 1.021442 s
# @@@wanted tol: 523.0751342773438
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002671310 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002465904 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002166667 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002108788 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002143763 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002354842 sec
# Iteration 0: Residual = 6.289201e+01, Time = 0.017015 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002388685 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002266738 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003119431 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002775085 sec
# Iteration 1: Residual = 7.154143e+00, Time = 0.018052 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002051035 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003797323 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.006114443 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003521199 sec
# Iteration 2: Residual = 3.125979e+00, Time = 0.024220 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.017687612 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.012610439 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.004578461 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002477784 sec
# Iteration 3: Residual = 1.856068e+00, Time = 0.061002 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002749057 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002033479 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002704544 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002663433 sec
# Iteration 4: Residual = 1.363490e+00, Time = 0.018264 s
#
# Performance Statistics:
# Total time: 0.163001 s
# Average time per iteration: 0.027711 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002502827 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001959924 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001985255 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002148365 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.018313530 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.010814052 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002584710 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002740911 sec
# Iteration 0: Residual = 1.602753e+00, Time = 0.154307 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002035249 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002467442 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002535432 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.010703001 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Iteration 1: Residual = 6.174670e-01, Time = 0.122665 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002543581 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002449914 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.004059671 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001959720 sec
# Iteration 2: Residual = 3.645344e-01, Time = 0.104663 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.004969664 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.010263482 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.004867460 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.005808436 sec
# Iteration 3: Residual = 8.925889e+00, Time = 0.123803 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002505276 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002583520 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001976979 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.006634277 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Iteration 4: Residual = 1.657363e-01, Time = 0.108726 s
#
# Performance Statistics:
# Total time: 0.708043 s
# Average time per iteration: 0.122833 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002836323 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002742128 sec
# @@@Iteration 4: Residual = 5.819575e+00, Time = 0.994351 s
# @@@wanted tol: 52.30751419067383
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.006423204 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002741875 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.006241762 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002160929 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002115944 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002526768 sec
# Iteration 0: Residual = 5.819575e+00, Time = 0.022288 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002577504 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.011558015 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.007248051 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.009058291 sec
# Iteration 1: Residual = 6.130911e-01, Time = 0.060918 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003590735 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002839270 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002965345 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003220085 sec
# Iteration 2: Residual = 3.056675e-01, Time = 0.023427 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.019530605 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002530046 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002426165 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002186813 sec
# Iteration 3: Residual = 2.299299e-01, Time = 0.056740 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002646473 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.004265815 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002074239 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002850277 sec
# Iteration 4: Residual = 1.333961e-01, Time = 0.024297 s
#
# Performance Statistics:
# Total time: 0.212815 s
# Average time per iteration: 0.037534 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003400872 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002914870 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002370337 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002166246 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.039305225 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.012997640 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002653213 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002741692 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Iteration 0: Residual = 4.882563e-01, Time = 0.169176 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002405814 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001962516 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.018666046 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002421962 sec
# Iteration 1: Residual = 6.629629e-02, Time = 0.113004 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002067349 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002546935 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002565327 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001955441 sec
#
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Iteration 2: Residual = 3.728981e-01, Time = 0.093491 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003339257 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.035804240 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002424720 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001999249 sec
# Iteration 3: Residual = 2.819371e-02, Time = 0.128701 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002402801 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.005355680 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002552864 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.005012433 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Iteration 4: Residual = 1.683623e-02, Time = 0.099135 s
#
# Performance Statistics:
# Total time: 0.700332 s
# Average time per iteration: 0.120701 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002127220 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002586881 sec
# @@@Iteration 5: Residual = 5.644504e-01, Time = 1.042483 s
# @@@wanted tol: 5.2307515144348145
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001991706 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.004575887 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002479241 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002649667 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002069703 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001981113 sec
# Iteration 0: Residual = 5.644504e-01, Time = 0.017340 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002566432 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002020999 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002623530 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002526797 sec
# Iteration 1: Residual = 5.307358e-02, Time = 0.017320 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002598716 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002422358 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002121800 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002553357 sec
# Iteration 2: Residual = 2.684435e-02, Time = 0.017334 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002008541 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002574625 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002841988 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002596482 sec
# Iteration 3: Residual = 3.486759e-02, Time = 0.017227 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002064663 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001994559 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002675488 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.004107616 sec
# Iteration 4: Residual = 1.194159e-02, Time = 0.018119 s
#
# Performance Statistics:
# Total time: 0.111684 s
# Average time per iteration: 0.017468 s
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.035107513 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002681923 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002572050 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001999962 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001991095 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002468255 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002491383 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.033510452 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Iteration 0: Residual = 3.905116e-01, Time = 0.137740 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002756125 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002701455 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002111317 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002116203 sec
# Iteration 1: Residual = 1.302800e-02, Time = 0.092293 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.005281114 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002091287 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002546103 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002405320 sec
# Iteration 2: Residual = 3.936923e-03, Time = 0.093714 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002533828 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001936585 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002772258 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002383398 sec
# Iteration 3: Residual = 2.901077e-02, Time = 0.094469 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.018786537 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.010791198 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003322390 sec
#
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002122190 sec
# Iteration 4: Residual = 7.980513e-03, Time = 0.126864 s
#
# Performance Statistics:
# Total time: 0.623833 s
# Average time per iteration: 0.109016 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002370463 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002685829 sec
# @@@Iteration 6: Residual = 6.053698e-02, Time = 0.888232 s
# @@@wanted tol: 0.5230751633644104
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002584567 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002085926 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.005364440 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002728305 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002276469 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.033999314 sec
# Iteration 0: Residual = 6.053698e-02, Time = 0.058929 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002064896 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002389875 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002136774 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002758976 sec
# Iteration 1: Residual = 4.490907e-03, Time = 0.017170 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002522696 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002559878 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002048068 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002139603 sec
# Iteration 2: Residual = 2.430513e-03, Time = 0.017601 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.007403363 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002249992 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002593636 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.005579625 sec
# Iteration 3: Residual = 4.587491e-03, Time = 0.031588 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002567191 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002037273 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002027176 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002724878 sec
# Iteration 4: Residual = 1.606339e-03, Time = 0.017724 s
#
# Performance Statistics:
# Total time: 0.177747 s
# Average time per iteration: 0.028603 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002072233 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002694952 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# ...
# Iteration 2: Residual = 1.607460e-04, Time = 0.059980 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002877215 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003375333 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002620932 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002537451 sec
# Iteration 3: Residual = 1.057033e-05, Time = 0.021372 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002760462 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002101513 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002129902 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002557934 sec
# Iteration 4: Residual = 7.731871e-06, Time = 0.018792 s
#
# Performance Statistics:
# Total time: 0.177081 s
# Average time per iteration: 0.029865 s
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002869163 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002554614 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002819549 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002938580 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002145505 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.013669475 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002447928 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.004603440 sec
# Iteration 0: Residual = 3.816627e-01, Time = 0.138140 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.005044135 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002554244 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002571878 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.012014707 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Iteration 1: Residual = 8.369278e-03, Time = 0.124003 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002116313 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002498781 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002137353 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002627302 sec
# Iteration 2: Residual = 8.214936e-04, Time = 0.103545 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002871230 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.010287468 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001976240 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002360888 sec
# Iteration 3: Residual = 2.341511e-04, Time = 0.120085 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003484872 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002008415 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002613324 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.010129206 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Iteration 4: Residual = 6.092506e-05, Time = 0.123409 s
#
# Performance Statistics:
# Total time: 0.693665 s
# Average time per iteration: 0.121836 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002532734 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002009540 sec
# @@@Iteration 21: Residual = 1.099849e-03, Time = 1.008398 s
# @@@wanted tol: 0.00010998488869518042
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001969890 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002512027 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002086055 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002471149 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002512769 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003305474 sec
# Iteration 0: Residual = 1.099849e-03, Time = 0.022172 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002057435 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002684802 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003284431 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002255127 sec
# Iteration 1: Residual = 3.927035e-05, Time = 0.018434 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002572323 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002482165 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002586076 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002014771 sec
# Iteration 2: Residual = 2.673625e-04, Time = 0.022988 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.018904861 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.005079769 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002594988 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002879017 sec
# Iteration 3: Residual = 9.882397e-06, Time = 0.052957 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003363535 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002804135 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002112380 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002153040 sec
# Iteration 4: Residual = 5.892851e-06, Time = 0.018665 s
#
# Performance Statistics:
# Total time: 0.161961 s
# Average time per iteration: 0.027043 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003079253 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002202847 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002604166 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002517015 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.018928777 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002160797 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.006085682 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002415516 sec
# Iteration 0: Residual = 3.822939e-01, Time = 0.144306 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002183780 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003320668 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.019922016 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.011847128 sec
# Iteration 1: Residual = 8.334449e-03, Time = 0.131153 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002954143 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002520915 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002571555 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002475863 sec
# Iteration 2: Residual = 8.045170e-04, Time = 0.100532 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.018930913 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.011330234 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002526962 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001965539 sec
# Iteration 3: Residual = 2.435008e-04, Time = 0.129836 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003118133 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002585552 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002459118 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.013204418 sec
# Iteration 4: Residual = 5.698101e-05, Time = 0.130367 s
#
# Performance Statistics:
# Total time: 0.719138 s
# Average time per iteration: 0.127239 s
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002409214 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002460304 sec
# @@@Iteration 22: Residual = 1.027227e-03, Time = 1.007423 s
# @@@wanted tol: 0.00010272274812450632
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002033574 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001965700 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002450880 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002712757 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002477170 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002552532 sec
# Iteration 0: Residual = 1.027227e-03, Time = 0.019333 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002985363 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001978225 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002567763 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.004140873 sec
# Iteration 1: Residual = 3.510306e-05, Time = 0.020434 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001985041 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002810254 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002327482 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.005407890 sec
# Iteration 2: Residual = 5.551551e-05, Time = 0.020605 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.012919085 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002812681 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002770187 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.003667027 sec
# Iteration 3: Residual = 9.576365e-06, Time = 0.030298 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002551992 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002772178 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002751113 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.001997054 sec
# Iteration 4: Residual = 6.981710e-06, Time = 0.017461 s
#
# Performance Statistics:
# Total time: 0.161220 s
# Average time per iteration: 0.021626 s
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002072373 sec
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002516422 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# Input Array Shape: (4, 3, 32, 32, 32, 16)
# Dest Shape: (4, 3, 8, 4, 8, 4, 8, 4, 8, 2)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002464891 sec
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.002344314 sec
# Input Array Shape: (98304,)
# Dest Shape: (24, 8, 8, 8, 8)
# multi-gpu wilson dslash total time: (without malloc free memcpy) :0.018302234 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 x_o = slover(
#       2     b=b__o, matvec=bistabcg_dslash, tol=1e-10, max_iter=1000000)
#
# Cell In[78], line 44, in slover(b, matvec, max_iter, tol, x0)
#      42 r = b-matvec(x)
#      43 r_c = _r_vec(r)
# ---> 44 e_c = bistabcg.slover(b=r_c, matvec=_r_matvec_p,
#      45                       tol=tol, max_iter=5)
#      46 # COARSE END
#      47 # FINE START
#      48 e = _p_vec(e_c)
#
# File /usr/local/lib/python3.8/dist-packages/pyqcu/bistabcg.py:43, in slover(b, matvec, max_iter, tol, x0)
#      41 p = r+(p-v*omega)*beta
#      42 r_norm2 = dot(r, r)
# ---> 43 v = matvec(p)
#      44 alpha = rho / dot(r_tilde, v)
#      45 s = r-v*alpha
#
# Cell In[78], line 23, in slover.<locals>._r_matvec_p(src)
#      22 def _r_matvec_p(src):
# ---> 23     return _r_vec(matvec(_p_vec(src)))
#
# Cell In[10], line 25, in bistabcg_dslash(src)
#      24 def bistabcg_dslash(src):
# ---> 25     return cg_dslash_no_dag(src)
#
# Cell In[10], line 4, in cg_dslash_no_dag(src)
#       2 tmp0 = cp.zeros_like(src)
#       3 tmp1 = cp.zeros_like(src)
# ----> 4 qcu.applyWilsonDslashQcu(
#       5     tmp0, src, gauge, set_ptrs, wilson_dslash_eo_params)
#       6 qcu.applyWilsonDslashQcu(
#       7     tmp1, tmp0, gauge, set_ptrs, wilson_dslash_oe_params)
#       8 return src-kappa**2*tmp1
#
# KeyboardInterrupt:

# %% [markdown]
# # MultiGrid - verify above.

# %%
# x_e  =b_e+kappa*D_eo(x_o)
qcu.applyWilsonDslashQcu(tmp, x_o, gauge, set_ptrs, wilson_dslash_eo_params)
x_e = b_e+kappa*tmp
# give qcu_fermion_out
qcu_fermion_out = cp.zeros_like(quda_fermion_out)
qcu_fermion_out[define._EVEN_] = x_e.reshape(
    quda_fermion_out[define._EVEN_].shape)
qcu_fermion_out[define._ODD_] = x_o.reshape(
    quda_fermion_out[define._ODD_].shape)
print(np.linalg.norm(qcu_fermion_out-quda_fermion_out) / \
    np.linalg.norm(quda_fermion_out))

# %%
x_o=io.hdf5_xxx2xxx(params,'x_o.h5')
_x_o=io.hdf5_xxx2xxx(params,'_x_o.h5')

# %%
x_o.flatten()[:50]

# %%
_x_o.flatten()[:50]

# %%
print(np.linalg.norm(_x_o-x_o) /
      np.linalg.norm(x_o))

# %% [markdown]
# # End for CG & BISTABCG. (pass, don't run this)

# %%
# cg_solver.end()
# bistabcg_solver.end()

# %% [markdown]
# # End for pyqcu. (pass, don't run this)

# %%
# qcu.applyEndQcu(set_ptrs, params)
# qcu.applyEndQcu(set_ptrs, wilson_dslash_eo_params)
# qcu.applyEndQcu(set_ptrs, wilson_dslash_oe_params)
# qcu.applyEndQcu(set_ptrs, wilson_dslash_eo_dag_params)
# qcu.applyEndQcu(set_ptrs, wilson_dslash_oe_dag_params)
