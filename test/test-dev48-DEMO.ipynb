# %%
import numpy as np
np.Inf = np.inf
import matplotlib.pyplot as plt
from scipy.sparse import diags
from scipy.sparse.linalg import spsolve
import time

class AdaptiveMultigridComplex:
    """
    自适应多重网格方法求解复数系统
    适用于求解复数系数的椭圆型偏微分方程
    """
    
    def __init__(self, n, max_levels=5, tolerance=1e-8, max_iterations=100):
        """
        初始化自适应多重网格求解器
        
        参数:
        n: 网格大小 (n x n)
        max_levels: 最大网格层数
        tolerance: 收敛容差
        max_iterations: 最大迭代次数
        """
        self.n = n
        self.max_levels = max_levels
        self.tolerance = tolerance
        self.max_iterations = max_iterations
        self.convergence_history = []
        self.level_info = []
        
    def create_complex_matrix(self, n, alpha=1.0, beta=1.0j):
        """
        创建复数系数矩阵 (离散化的复数椭圆算子)
        -α∇²u - iβu = f
        """
        print(f"创建 {n}x{n} 复数系数矩阵...")
        print(f"  系数: α = {alpha}, β = {beta}")
        
        h = 1.0 / (n + 1)  # 网格间距
        
        # 主对角线: 4α/h² + iβ
        main_diag = (4 * alpha / h**2 + beta) * np.ones(n**2, dtype=complex)
        
        # 上下对角线: -α/h²
        off_diag_1 = (-alpha / h**2) * np.ones(n**2 - 1, dtype=complex)
        off_diag_n = (-alpha / h**2) * np.ones(n**2 - n, dtype=complex)
        
        # 处理边界条件 (移除跨行的连接)
        for i in range(n-1, n**2-1, n):
            off_diag_1[i] = 0
            
        A = diags([off_diag_n, off_diag_1, main_diag, off_diag_1, off_diag_n],
                 [-n, -1, 0, 1, n], format='csr')
        
        print(f"  矩阵创建完成: {A.shape}, 非零元素: {A.nnz}")
        return A
    
    def create_rhs(self, n, func_type='sine'):
        """创建右端项"""
        h = 1.0 / (n + 1)
        x = np.linspace(h, 1-h, n)
        y = np.linspace(h, 1-h, n)
        X, Y = np.meshgrid(x, y)
        
        if func_type == 'sine':
            # 复数正弦函数
            f = np.sin(2*np.pi*X) * np.sin(2*np.pi*Y) * (1 + 1j)
        elif func_type == 'exponential':
            # 复数指数函数
            f = np.exp(X + 1j*Y)
        else:
            # 默认函数
            f = np.ones((n, n), dtype=complex)
            
        return f.flatten()
    
    def restrict(self, u_fine):
        """限制算子：细网格到粗网格"""
        n_fine = int(np.sqrt(len(u_fine)))
        n_coarse = n_fine // 2
        
        if n_coarse < 2:
            return u_fine
            
        u_fine_2d = u_fine.reshape((n_fine, n_fine))
        u_coarse_2d = np.zeros((n_coarse, n_coarse), dtype=complex)
        
        # 全权重限制 (9点模板)
        for i in range(n_coarse):
            for j in range(n_coarse):
                ii, jj = 2*i+1, 2*j+1
                weight_sum = 0
                value_sum = 0
                
                for di in [-1, 0, 1]:
                    for dj in [-1, 0, 1]:
                        ni, nj = ii + di, jj + dj
                        if 0 <= ni < n_fine and 0 <= nj < n_fine:
                            if di == 0 and dj == 0:
                                weight = 4
                            elif di == 0 or dj == 0:
                                weight = 2
                            else:
                                weight = 1
                            weight_sum += weight
                            value_sum += weight * u_fine_2d[ni, nj]
                
                u_coarse_2d[i, j] = value_sum / weight_sum if weight_sum > 0 else 0
                
        return u_coarse_2d.flatten()
    
    def prolongate(self, u_coarse, n_fine):
        """延拓算子：粗网格到细网格"""
        n_coarse = int(np.sqrt(len(u_coarse)))
        u_coarse_2d = u_coarse.reshape((n_coarse, n_coarse))
        u_fine_2d = np.zeros((n_fine, n_fine), dtype=complex)
        
        # 双线性插值
        for i in range(n_fine):
            for j in range(n_fine):
                # 计算在粗网格中的位置
                i_coarse = (i * n_coarse) / n_fine
                j_coarse = (j * n_coarse) / n_fine
                
                i0, j0 = int(i_coarse), int(j_coarse)
                i1, j1 = min(i0 + 1, n_coarse - 1), min(j0 + 1, n_coarse - 1)
                
                # 插值权重
                wi = i_coarse - i0
                wj = j_coarse - j0
                
                # 双线性插值
                u_fine_2d[i, j] = ((1-wi)*(1-wj)*u_coarse_2d[i0, j0] +
                                   wi*(1-wj)*u_coarse_2d[i1, j0] +
                                   (1-wi)*wj*u_coarse_2d[i0, j1] +
                                   wi*wj*u_coarse_2d[i1, j1])
        
        return u_fine_2d.flatten()
    
    def smooth(self, A, b, u, num_iterations=3, method='jacobi'):
        """光滑算子"""
        n = len(u)
        
        if method == 'jacobi':
            # 复数Jacobi迭代
            D = A.diagonal()
            R = A - diags(D, format='csr')
            
            for _ in range(num_iterations):
                u = (b - R.dot(u)) / D
                
        elif method == 'gauss_seidel':
            # 复数Gauss-Seidel迭代
            for _ in range(num_iterations):
                for i in range(n):
                    sum_val = 0
                    for j in range(n):
                        if i != j:
                            sum_val += A[i, j] * u[j]
                    u[i] = (b[i] - sum_val) / A[i, i]
                    
        return u
    
    def compute_residual(self, A, b, u):
        """计算残差"""
        return b - A.dot(u)
    
    def v_cycle(self, A_hierarchy, b_hierarchy, u_hierarchy, level=0):
        """V-循环"""
        current_level = len(A_hierarchy) - 1 - level
        A = A_hierarchy[current_level]
        b = b_hierarchy[current_level]
        u = u_hierarchy[current_level]
        
        print(f"  V-循环 level {level}, 网格大小: {int(np.sqrt(len(u)))}x{int(np.sqrt(len(u)))}")
        
        # 如果是最粗网格，直接求解
        if current_level == 0 or level >= self.max_levels - 1:
            print(f"    最粗网格直接求解...")
            u_hierarchy[current_level] = spsolve(A, b)
            return u_hierarchy[current_level]
        
        # 前光滑
        print(f"    前光滑...")
        u = self.smooth(A, b, u, num_iterations=2, method='jacobi')
        u_hierarchy[current_level] = u
        
        # 计算残差
        residual = self.compute_residual(A, b, u)
        residual_norm = np.linalg.norm(residual)
        print(f"    残差范数: {residual_norm:.2e}")
        
        # 限制残差到粗网格
        if current_level > 0:
            r_coarse = self.restrict(residual)
            b_hierarchy[current_level - 1] = r_coarse
            u_hierarchy[current_level - 1] = np.zeros_like(r_coarse)
            
            # 递归调用粗网格
            e_coarse = self.v_cycle(A_hierarchy, b_hierarchy, u_hierarchy, level + 1)
            
            # 延拓误差修正
            n_fine = int(np.sqrt(len(u)))
            e_fine = self.prolongate(e_coarse, n_fine)
            u = u + e_fine
            u_hierarchy[current_level] = u
        
        # 后光滑
        print(f"    后光滑...")
        u = self.smooth(A, b, u, num_iterations=2, method='jacobi')
        u_hierarchy[current_level] = u
        
        return u
    
    def adaptive_criterion(self, residual_norms):
        """自适应准则：决定是否需要调整网格层数"""
        if len(residual_norms) < 3:
            return False
            
        # 计算收敛率
        conv_rate = residual_norms[-1] / residual_norms[-2] if residual_norms[-2] != 0 else 1
        
        # 如果收敛太慢，建议增加网格层数
        return conv_rate > 0.8
    
    def solve(self, alpha=1.0, beta=1.0j, func_type='sine'):
        """主求解函数"""
        print("="*60)
        print("开始自适应多重网格复数求解")
        print("="*60)
        
        start_time = time.time()
        
        # 设置网格层次结构
        levels = []
        current_n = self.n
        
        print(f"构建网格层次结构:")
        while current_n >= 4 and len(levels) < self.max_levels:
            levels.append(current_n)
            print(f"  Level {len(levels)-1}: {current_n}x{current_n}")
            current_n = current_n // 2
            
        num_levels = len(levels)
        print(f"总共 {num_levels} 层网格")
        
        # 创建各层矩阵和右端项
        print(f"\n构建各层系统矩阵:")
        A_hierarchy = []
        b_hierarchy = []
        u_hierarchy = []
        
        for i, n in enumerate(levels):
            print(f"Level {i}:")
            A = self.create_complex_matrix(n, alpha, beta)
            b = self.create_rhs(n, func_type)
            u = np.zeros(n**2, dtype=complex)
            
            A_hierarchy.append(A)
            b_hierarchy.append(b)
            u_hierarchy.append(u)
        
        # 反转层次（从细到粗）
        A_hierarchy.reverse()
        b_hierarchy.reverse()
        u_hierarchy.reverse()
        
        print(f"\n开始多重网格迭代:")
        print("-" * 40)
        
        # 主迭代循环
        for iteration in range(self.max_iterations):
            print(f"\n迭代 {iteration + 1}:")
            
            # 执行V-循环
            u_hierarchy[-1] = self.v_cycle(A_hierarchy, b_hierarchy, u_hierarchy)
            
            # 计算最细网格上的残差
            finest_residual = self.compute_residual(A_hierarchy[-1], b_hierarchy[-1], u_hierarchy[-1])
            residual_norm = np.linalg.norm(finest_residual)
            self.convergence_history.append(residual_norm)
            
            print(f"  迭代 {iteration + 1} 完成，残差范数: {residual_norm:.2e}")
            
            # 检查收敛
            if residual_norm < self.tolerance:
                print(f"  ✓ 收敛达到容差 {self.tolerance}")
                break
                
            # 自适应准则
            if self.adaptive_criterion(self.convergence_history):
                print(f"  注意: 收敛较慢，可能需要更多网格层")
        
        solve_time = time.time() - start_time
        
        print("\n" + "="*60)
        print("求解完成!")
        print(f"总迭代次数: {len(self.convergence_history)}")
        print(f"最终残差: {self.convergence_history[-1]:.2e}")
        print(f"求解时间: {solve_time:.4f} 秒")
        print("="*60)
        
        return u_hierarchy[-1].reshape((self.n, self.n))
    
    def verify_solution(self, solution, alpha=1.0, beta=1.0j, func_type='sine'):
        """验证解的正确性"""
        print("\n验证解的正确性:")
        print("-" * 30)
        
        # 重新计算矩阵和右端项
        A = self.create_complex_matrix(self.n, alpha, beta)
        b = self.create_rhs(self.n, func_type)
        u_flat = solution.flatten()
        
        # 计算 Au - b
        residual = A.dot(u_flat) - b
        residual_norm = np.linalg.norm(residual)
        relative_error = residual_norm / np.linalg.norm(b)
        
        print(f"解的实部范围: [{np.real(solution).min():.4f}, {np.real(solution).max():.4f}]")
        print(f"解的虚部范围: [{np.imag(solution).min():.4f}, {np.imag(solution).max():.4f}]")
        print(f"解的模长范围: [{np.abs(solution).min():.4f}, {np.abs(solution).max():.4f}]")
        print(f"验证残差范数: {residual_norm:.2e}")
        print(f"相对误差: {relative_error:.2e}")
        
        if relative_error < 1e-6:
            print("✓ 解验证通过!")
        else:
            print("⚠ 解可能存在精度问题")
            
        return residual_norm, relative_error
    
    def plot_results(self, solution):
        """可视化结果"""
        print("\n生成可视化图像...")
        
        fig, axes = plt.subplots(2, 3, figsize=(15, 10))
        fig.suptitle('Adaptive Multigrid Complex Solution Results', fontsize=16)
        
        x = np.linspace(0, 1, self.n)
        y = np.linspace(0, 1, self.n)
        X, Y = np.meshgrid(x, y)
        
        # 解的实部
        im1 = axes[0, 0].contourf(X, Y, np.real(solution), levels=20, cmap='RdBu_r')
        axes[0, 0].set_title('Solution - Real Part')
        axes[0, 0].set_xlabel('x')
        axes[0, 0].set_ylabel('y')
        plt.colorbar(im1, ax=axes[0, 0])
        
        # 解的虚部
        im2 = axes[0, 1].contourf(X, Y, np.imag(solution), levels=20, cmap='RdBu_r')
        axes[0, 1].set_title('Solution - Imaginary Part')
        axes[0, 1].set_xlabel('x')
        axes[0, 1].set_ylabel('y')
        plt.colorbar(im2, ax=axes[0, 1])
        
        # 解的模长
        im3 = axes[0, 2].contourf(X, Y, np.abs(solution), levels=20, cmap='viridis')
        axes[0, 2].set_title('Solution - Magnitude')
        axes[0, 2].set_xlabel('x')
        axes[0, 2].set_ylabel('y')
        plt.colorbar(im3, ax=axes[0, 2])
        
        # 收敛历史
        axes[1, 0].semilogy(range(1, len(self.convergence_history) + 1), 
                           self.convergence_history, 'b-o', markersize=4)
        axes[1, 0].set_title('Convergence History')
        axes[1, 0].set_xlabel('Iteration')
        axes[1, 0].set_ylabel('Residual Norm')
        axes[1, 0].grid(True)
        
        # 解的相位
        phase = np.angle(solution)
        im4 = axes[1, 1].contourf(X, Y, phase, levels=20, cmap='hsv')
        axes[1, 1].set_title('Solution - Phase')
        axes[1, 1].set_xlabel('x')
        axes[1, 1].set_ylabel('y')
        plt.colorbar(im4, ax=axes[1, 1])
        
        # 3D表面图（模长）
        ax3d = fig.add_subplot(2, 3, 6, projection='3d')
        surf = ax3d.plot_surface(X, Y, np.abs(solution), cmap='viridis', alpha=0.8)
        ax3d.set_title('Solution Magnitude - 3D View')
        ax3d.set_xlabel('x')
        ax3d.set_ylabel('y')
        ax3d.set_zlabel('|u|')
        
        plt.tight_layout()
        plt.show()
        
        print("可视化完成!")

# %%
# 主程序
if __name__ == "__main__":
    print("自适应多重网格复数求解器演示")
    print("=" * 50)
    
    # 创建求解器实例
    n = 64  # 网格大小
    solver = AdaptiveMultigridComplex(n=n, max_levels=4, tolerance=1e-6, max_iterations=10000)
    
    # 测试不同的问题参数
    test_cases = [
        {"alpha": 1.0, "beta": 1.0j, "func_type": "sine", "name": "复数椭圆问题 (正弦右端项)"},
        {"alpha": 2.0, "beta": 0.5j, "func_type": "exponential", "name": "修正复数问题 (指数右端项)"}
    ]
    
    for i, case in enumerate(test_cases):
        print(f"\n{'='*80}")
        print(f"测试案例 {i+1}: {case['name']}")
        print(f"{'='*80}")
        
        # 求解
        solution = solver.solve(alpha=case["alpha"], beta=case["beta"], func_type=case["func_type"])
        
        # 验证
        residual_norm, relative_error = solver.verify_solution(
            solution, alpha=case["alpha"], beta=case["beta"], func_type=case["func_type"]
        )
        
        # 可视化
        solver.plot_results(solution)
        
        # 性能统计
        print(f"\n性能统计:")
        print(f"网格大小: {n}x{n}")
        print(f"未知数个数: {n**2}")
        print(f"收敛迭代次数: {len(solver.convergence_history)}")
        print(f"最终残差: {solver.convergence_history[-1]:.2e}")
        
        # 重置收敛历史
        solver.convergence_history = []
    
    print(f"\n{'='*80}")
    print("所有测试完成!")
    print(f"{'='*80}")
# Out:
# 自适应多重网格复数求解器演示
# ==================================================
#
# ================================================================================
# 测试案例 1: 复数椭圆问题 (正弦右端项)
# ================================================================================
# ============================================================
# 开始自适应多重网格复数求解
# ============================================================
# 构建网格层次结构:
#   Level 0: 64x64
#   Level 1: 32x32
#   Level 2: 16x16
#   Level 3: 8x8
# 总共 4 层网格
#
# 构建各层系统矩阵:
# Level 0:
# 创建 64x64 复数系数矩阵...
#   系数: α = 1.0, β = 1j
#   矩阵创建完成: (4096, 4096), 非零元素: 20224
# Level 1:
# 创建 32x32 复数系数矩阵...
#   系数: α = 1.0, β = 1j
#   矩阵创建完成: (1024, 1024), 非零元素: 4992
# Level 2:
# 创建 16x16 复数系数矩阵...
#   系数: α = 1.0, β = 1j
#   矩阵创建完成: (256, 256), 非零元素: 1216
# Level 3:
# 创建 8x8 复数系数矩阵...
#   系数: α = 1.0, β = 1j
#   矩阵创建完成: (64, 64), 非零元素: 288
#
# 开始多重网格迭代:
# ----------------------------------------
#
# 迭代 1:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 4.55e+01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.19e+01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 9.31e+00
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 1 完成，残差范数: 6.77e+01
#
# 迭代 2:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 5.23e+01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.77e+01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.36e+00
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2 完成，残差范数: 3.90e+01
#
# 迭代 3:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.14e+01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.22e+01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.13e+00
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 3 完成，残差范数: 3.59e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 4:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.93e+01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.07e+01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.49e+00
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 4 完成，残差范数: 3.14e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 5:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.41e+01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 8.70e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.72e+00
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 5 完成，残差范数: 2.62e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 6:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.03e+01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 7.80e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.52e+00
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 6 完成，残差范数: 2.74e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 7:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.01e+01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 6.99e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.17e+00
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 7 完成，残差范数: 2.43e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 8:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.69e+01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 5.80e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.81e+00
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 8 完成，残差范数: 2.23e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 9:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.56e+01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 5.46e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.72e+00
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 9 完成，残差范数: 2.21e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 10:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.50e+01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.90e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.48e+00
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 10 完成，残差范数: 1.98e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 11:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.31e+01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.31e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.36e+00
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 11 完成，残差范数: 1.91e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 12:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.26e+01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.10e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.27e+00
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 12 完成，残差范数: 1.82e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 13:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.18e+01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.72e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.13e+00
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 13 完成，残差范数: 1.68e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 14:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.08e+01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.45e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.09e+00
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 14 完成，残差范数: 1.63e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 15:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.05e+01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.27e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.01e+00
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 15 完成，残差范数: 1.53e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 16:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 9.77e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.02e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 9.36e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 16 完成，残差范数: 1.46e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 17:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 9.28e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.88e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 8.99e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 17 完成，残差范数: 1.40e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 18:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 8.87e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.72e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 8.36e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 18 完成，残差范数: 1.32e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 19:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 8.33e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.56e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 7.99e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 19 完成，残差范数: 1.26e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 20:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 7.99e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.44e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 7.58e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 20 完成，残差范数: 1.20e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 21:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 7.58e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.31e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 7.16e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 21 完成，残差范数: 1.14e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 22:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 7.20e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.20e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 6.86e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 22 完成，残差范数: 1.09e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 23:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 6.89e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.10e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 6.49e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 23 完成，残差范数: 1.04e+01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 24:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 6.54e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.99e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 6.19e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 24 完成，残差范数: 9.91e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 25:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 6.25e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.90e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.91e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 25 完成，残差范数: 9.45e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 26:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 5.95e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.81e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.61e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 26 完成，残差范数: 9.00e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 27:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 5.67e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.72e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.36e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 27 完成，残差范数: 8.59e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 28:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 5.41e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.64e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.10e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 28 完成，残差范数: 8.19e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 29:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 5.15e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.56e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.86e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 29 完成，残差范数: 7.81e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 30:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 4.91e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.49e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.64e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 30 完成，残差范数: 7.45e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 31:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 4.69e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.42e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.42e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 31 完成，残差范数: 7.10e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 32:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 4.47e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.36e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.22e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 32 完成，残差范数: 6.77e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 33:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 4.26e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.29e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.02e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 33 完成，残差范数: 6.45e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 34:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 4.06e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.23e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.83e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 34 完成，残差范数: 6.15e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 35:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.87e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.18e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.66e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 35 完成，残差范数: 5.87e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 36:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.69e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.12e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.48e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 36 完成，残差范数: 5.59e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 37:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.52e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.07e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.32e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 37 完成，残差范数: 5.34e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 38:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.36e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.02e+00
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.17e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 38 完成，残差范数: 5.09e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 39:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.20e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 9.72e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.02e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 39 完成，残差范数: 4.85e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 40:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.05e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 9.26e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.88e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 40 完成，残差范数: 4.63e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 41:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.91e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 8.83e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.75e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 41 完成，残差范数: 4.41e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 42:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.78e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 8.42e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.62e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 42 完成，残差范数: 4.21e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 43:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.65e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 8.03e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.50e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 43 完成，残差范数: 4.01e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 44:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.52e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 7.66e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.38e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 44 完成，残差范数: 3.82e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 45:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.41e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 7.30e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.27e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 45 完成，残差范数: 3.65e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 46:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.30e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 6.96e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.17e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 46 完成，残差范数: 3.48e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 47:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.19e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 6.64e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.06e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 47 完成，残差范数: 3.32e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 48:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.09e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 6.33e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.97e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 48 完成，残差范数: 3.16e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 49:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.99e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 6.04e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.88e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 49 完成，残差范数: 3.01e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 50:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.90e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 5.76e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.79e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 50 完成，残差范数: 2.87e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 51:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.81e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 5.49e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.71e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 51 完成，残差范数: 2.74e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 52:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.73e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 5.23e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.63e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 52 完成，残差范数: 2.61e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 53:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.65e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.99e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.55e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 53 完成，残差范数: 2.49e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 54:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.57e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.76e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.48e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 54 完成，残差范数: 2.38e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 55:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.50e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.54e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.41e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 55 完成，残差范数: 2.27e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 56:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.43e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.33e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.35e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 56 完成，残差范数: 2.16e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 57:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.36e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.13e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.28e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 57 完成，残差范数: 2.06e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 58:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.30e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.94e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.22e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 58 完成，残差范数: 1.97e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 59:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.24e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.75e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.17e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 59 完成，残差范数: 1.87e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 60:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.18e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.58e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.11e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 60 完成，残差范数: 1.79e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 61:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.12e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.41e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.06e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 61 完成，残差范数: 1.70e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 62:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.07e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.25e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.01e-01
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 62 完成，残差范数: 1.62e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 63:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.02e+00
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.10e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 9.65e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 63 完成，残差范数: 1.55e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 64:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 9.75e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.96e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 9.20e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 64 完成，残差范数: 1.48e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 65:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 9.30e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.82e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 8.77e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 65 完成，残差范数: 1.41e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 66:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 8.87e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.69e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 8.36e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 66 完成，残差范数: 1.34e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 67:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 8.45e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.56e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 7.97e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 67 完成，残差范数: 1.28e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 68:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 8.06e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.45e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 7.60e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 68 完成，残差范数: 1.22e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 69:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 7.69e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.33e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 7.25e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 69 完成，残差范数: 1.16e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 70:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 7.33e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.22e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 6.91e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 70 完成，残差范数: 1.11e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 71:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 6.99e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.12e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 6.59e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 71 完成，残差范数: 1.06e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 72:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 6.67e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.02e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 6.29e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 72 完成，残差范数: 1.01e+00
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 73:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 6.36e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.93e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.99e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 73 完成，残差范数: 9.63e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 74:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 6.06e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.84e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.72e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 74 完成，残差范数: 9.18e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 75:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 5.78e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.75e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.45e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 75 完成，残差范数: 8.76e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 76:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 5.51e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.67e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.20e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 76 完成，残差范数: 8.35e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 77:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 5.26e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.59e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.96e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 77 完成，残差范数: 7.96e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 78:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 5.01e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.52e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.73e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 78 完成，残差范数: 7.59e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 79:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 4.78e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.45e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.51e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 79 完成，残差范数: 7.24e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 80:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 4.56e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.38e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.30e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 80 完成，残差范数: 6.90e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 81:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 4.35e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.32e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.10e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 81 完成，残差范数: 6.58e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 82:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 4.14e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.26e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.91e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 82 完成，残差范数: 6.28e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 83:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.95e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.20e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.73e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 83 完成，残差范数: 5.99e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 84:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.77e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.14e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.55e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 84 完成，残差范数: 5.71e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 85:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.59e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.09e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.39e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 85 完成，残差范数: 5.44e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 86:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.43e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.04e-01
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.23e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 86 完成，残差范数: 5.19e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 87:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.27e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 9.91e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.08e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 87 完成，残差范数: 4.95e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 88:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.12e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 9.45e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.94e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 88 完成，残差范数: 4.72e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 89:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.97e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 9.01e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.80e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 89 完成，残差范数: 4.50e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 90:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.83e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 8.59e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.67e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 90 完成，残差范数: 4.29e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 91:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.70e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 8.19e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.55e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 91 完成，残差范数: 4.09e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 92:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.58e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 7.81e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.43e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 92 完成，残差范数: 3.90e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 93:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.46e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 7.45e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.32e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 93 完成，残差范数: 3.72e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 94:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.34e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 7.10e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.21e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 94 完成，残差范数: 3.55e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 95:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.24e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 6.77e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.11e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 95 完成，残差范数: 3.38e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 96:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.13e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 6.46e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.01e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 96 完成，残差范数: 3.23e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 97:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.03e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 6.16e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.91e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 97 完成，残差范数: 3.08e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 98:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.94e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 5.87e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.83e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 98 完成，残差范数: 2.93e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 99:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.85e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 5.60e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.74e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 99 完成，残差范数: 2.80e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 100:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.76e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 5.34e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.66e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 100 完成，残差范数: 2.67e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 101:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.68e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 5.09e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.58e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 101 完成，残差范数: 2.54e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 102:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.60e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.85e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.51e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 102 完成，残差范数: 2.43e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 103:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.53e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.63e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.44e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 103 完成，残差范数: 2.31e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 104:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.46e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.41e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.37e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 104 完成，残差范数: 2.21e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 105:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.39e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.21e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.31e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 105 完成，残差范数: 2.10e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 106:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.33e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.01e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.25e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 106 完成，残差范数: 2.01e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 107:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.27e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.83e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.19e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 107 完成，残差范数: 1.91e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 108:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.21e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.65e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.13e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 108 完成，残差范数: 1.83e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 109:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.15e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.48e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.08e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 109 完成，残差范数: 1.74e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 110:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.10e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.32e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.03e-02
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 110 完成，残差范数: 1.66e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 111:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.05e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.16e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 9.83e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 111 完成，残差范数: 1.58e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 112:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.00e-01
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.02e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 9.38e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 112 完成，残差范数: 1.51e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 113:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 9.53e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.88e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 8.94e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 113 完成，残差范数: 1.44e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 114:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 9.09e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.74e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 8.53e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 114 完成，残差范数: 1.37e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 115:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 8.68e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.62e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 8.13e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 115 完成，残差范数: 1.31e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 116:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 8.28e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.49e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 7.75e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 116 完成，残差范数: 1.25e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 117:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 7.89e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.38e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 7.39e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 117 完成，残差范数: 1.19e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 118:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 7.53e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.27e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 7.05e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 118 完成，残差范数: 1.14e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 119:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 7.18e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.16e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 6.72e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 119 完成，残差范数: 1.08e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 120:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 6.85e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 2.06e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 6.41e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 120 完成，残差范数: 1.03e-01
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 121:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 6.54e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.97e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 6.11e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 121 完成，残差范数: 9.86e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 122:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 6.24e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.87e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.83e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 122 完成，残差范数: 9.40e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 123:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 5.95e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.79e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.56e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 123 完成，残差范数: 8.97e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 124:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 5.68e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.70e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.30e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 124 完成，残差范数: 8.55e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 125:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 5.42e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.63e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.05e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 125 完成，残差范数: 8.16e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 126:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 5.17e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.55e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.82e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 126 完成，残差范数: 7.78e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 127:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 4.94e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.48e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.59e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 127 完成，残差范数: 7.42e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 128:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 4.71e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.41e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.38e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 128 完成，残差范数: 7.08e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 129:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 4.50e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.34e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.18e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 129 完成，残差范数: 6.75e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 130:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 4.29e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.28e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.98e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 130 完成，残差范数: 6.44e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 131:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 4.09e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.22e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.80e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 131 完成，残差范数: 6.14e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 132:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.91e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.16e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.62e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 132 完成，残差范数: 5.86e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 133:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.73e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.11e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.45e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 133 完成，残差范数: 5.59e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 134:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.56e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.06e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.29e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 134 完成，残差范数: 5.34e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 135:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.40e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 1.01e-02
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.14e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 135 完成，残差范数: 5.09e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 136:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.25e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 9.63e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.99e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 136 完成，残差范数: 4.86e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 137:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 3.10e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 9.18e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.86e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 137 完成，残差范数: 4.63e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 138:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.96e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 8.76e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.72e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 138 完成，残差范数: 4.42e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 139:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.83e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 8.35e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.60e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 139 完成，残差范数: 4.22e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 140:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.70e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 7.96e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.48e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 140 完成，残差范数: 4.03e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 141:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.58e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 7.59e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.36e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 141 完成，残差范数: 3.84e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 142:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.46e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 7.24e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.25e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 142 完成，残差范数: 3.67e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 143:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.35e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 6.90e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.15e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 143 完成，残差范数: 3.50e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 144:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.25e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 6.58e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 2.05e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 144 完成，残差范数: 3.34e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 145:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.15e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 6.28e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.95e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 145 完成，残差范数: 3.19e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 146:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 2.05e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 5.99e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.86e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 146 完成，残差范数: 3.04e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 147:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.96e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 5.71e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.77e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 147 完成，残差范数: 2.90e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 148:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.88e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 5.44e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.69e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 148 完成，残差范数: 2.77e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 149:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.79e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 5.19e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.61e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 149 完成，残差范数: 2.65e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 150:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.71e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.95e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.54e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 150 完成，残差范数: 2.53e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 151:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.64e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.72e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.47e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 151 完成，残差范数: 2.41e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 152:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.57e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.50e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.40e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 152 完成，残差范数: 2.30e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 153:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.50e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.29e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.33e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 153 完成，残差范数: 2.20e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 154:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.44e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.09e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.27e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 154 完成，残差范数: 2.10e-02
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 155:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.37e-02
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.90e-03
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 1.21e-03
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
# ...
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.54e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.26e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2188 完成，残差范数: 1.26e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2189:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.25e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.91e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.28e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2189 完成，残差范数: 1.25e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2190:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.25e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.65e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.99e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2190 完成，残差范数: 1.25e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2191:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.24e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.83e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.22e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2191 完成，残差范数: 1.24e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2192:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.24e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.67e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.88e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2192 完成，残差范数: 1.23e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2193:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.23e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.87e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.21e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2193 完成，残差范数: 1.23e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2194:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.23e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.99e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.61e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2194 完成，残差范数: 1.22e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2195:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.22e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.71e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.59e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2195 完成，残差范数: 1.22e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2196:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.21e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.01e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.26e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2196 完成，残差范数: 1.21e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2197:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.21e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.78e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.17e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2197 完成，残差范数: 1.21e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2198:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.20e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.02e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.29e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2198 完成，残差范数: 1.20e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2199:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.20e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.75e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.59e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2199 完成，残差范数: 1.19e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2200:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.19e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.88e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 6.20e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2200 完成，残差范数: 1.19e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2201:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.19e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.79e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.35e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2201 完成，残差范数: 1.18e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2202:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.18e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.26e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.68e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2202 完成，残差范数: 1.18e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2203:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.17e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.84e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 6.06e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2203 完成，残差范数: 1.17e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2204:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.17e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.02e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.56e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2204 完成，残差范数: 1.17e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2205:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.16e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.90e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 6.41e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2205 完成，残差范数: 1.16e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2206:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.16e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.35e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.69e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2206 完成，残差范数: 1.16e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2207:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.15e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.30e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 6.16e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2207 完成，残差范数: 1.15e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2208:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.15e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.00e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 6.57e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2208 完成，残差范数: 1.15e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2209:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.14e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.81e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 6.48e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2209 完成，残差范数: 1.14e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2210:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.14e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.98e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 6.75e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2210 完成，残差范数: 1.13e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2211:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.13e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.88e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 6.45e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2211 完成，残差范数: 1.13e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2212:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.13e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.57e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.63e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2212 完成，残差范数: 1.12e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2213:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.12e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.76e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.12e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2213 完成，残差范数: 1.12e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2214:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.12e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.88e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.18e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2214 完成，残差范数: 1.11e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2215:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.11e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.70e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.27e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2215 完成，残差范数: 1.11e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2216:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.11e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.64e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.18e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2216 完成，残差范数: 1.10e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2217:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.10e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.63e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.46e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2217 完成，残差范数: 1.10e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2218:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.10e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.82e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.86e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2218 完成，残差范数: 1.09e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2219:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.09e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.80e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.00e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2219 完成，残差范数: 1.09e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2220:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.09e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.85e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.52e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2220 完成，残差范数: 1.08e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2221:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.08e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.95e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.74e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2221 完成，残差范数: 1.08e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2222:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.08e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.73e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.93e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2222 完成，残差范数: 1.07e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2223:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.07e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 4.17e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.23e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2223 完成，残差范数: 1.07e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2224:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.07e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.75e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.97e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2224 完成，残差范数: 1.06e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2225:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.06e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.53e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.83e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2225 完成，残差范数: 1.06e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2226:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.06e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.96e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.31e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2226 完成，残差范数: 1.05e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2227:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.05e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.64e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 5.47e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2227 完成，残差范数: 1.05e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2228:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.05e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.73e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.94e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2228 完成，残差范数: 1.04e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2229:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.04e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.55e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.99e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2229 完成，残差范数: 1.04e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2230:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.04e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.73e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.07e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2230 完成，残差范数: 1.03e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2231:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.03e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.79e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.42e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2231 完成，残差范数: 1.03e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2232:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.03e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.72e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.56e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2232 完成，残差范数: 1.02e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2233:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.02e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.87e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 3.63e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2233 完成，残差范数: 1.02e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2234:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.02e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.70e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.09e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2234 完成，残差范数: 1.01e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2235:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.01e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.60e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.49e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2235 完成，残差范数: 1.01e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2236:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.01e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.67e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.45e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2236 完成，残差范数: 1.00e-06
#   注意: 收敛较慢，可能需要更多网格层
#
# 迭代 2237:
#   V-循环 level 0, 网格大小: 64x64
#     前光滑...
#     残差范数: 1.00e-06
#   V-循环 level 1, 网格大小: 32x32
#     前光滑...
#     残差范数: 3.60e-13
#   V-循环 level 2, 网格大小: 16x16
#     前光滑...
#     残差范数: 4.60e-14
#   V-循环 level 3, 网格大小: 8x8
#     最粗网格直接求解...
#     后光滑...
#     后光滑...
#     后光滑...
#   迭代 2237 完成，残差范数: 1.00e-06
#   ✓ 收敛达到容差 1e-06
#
# ============================================================
# 求解完成!
# 总迭代次数: 2237
# 最终残差: 1.00e-06
# 求解时间: 29.9747 秒
# ============================================================
#
# 验证解的正确性:
# ------------------------------
# 创建 64x64 复数系数矩阵...
#   系数: α = 2.0, β = 0.5j
#   矩阵创建完成: (4096, 4096), 非零元素: 20224
# 解的实部范围: [0.0002, 0.0550]
# 解的虚部范围: [0.0001, 0.0307]
# 解的模长范围: [0.0003, 0.0618]
# 验证残差范数: 1.00e-06
# 相对误差: 8.76e-09
# ✓ 解验证通过!
#
# 生成可视化图像...
# 可视化完成!
#
# 性能统计:
# 网格大小: 64x64
# 未知数个数: 4096
# 收敛迭代次数: 2237
# 最终残差: 1.00e-06
#
# ================================================================================
# 所有测试完成!
# ================================================================================
